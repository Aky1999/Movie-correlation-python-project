# %%
import pandas as pd
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

import seaborn as sns

# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8)

# %%
df1 = pd.read_csv(r"C:\Users\raoak\Downloads\movies.csv\movies.csv")

# %%
#see the data
df1
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
#check if there is missing values
for col in df1.columns:
    percnt_missing = np.mean(df1[col].isnull())
    print('{} - {}%'.format(col,percnt_missing))
# Out:
# name - 0.0%
# rating - 0.0%
# genre - 0.0%
# year - 0.0%
# released - 0.0%
# score - 0.0%
# votes - 0.0%
# director - 0.0%
# writer - 0.0%
# star - 0.0%
# country - 0.0%
# budget - 0.0%
# gross - 0.0%
# company - 0.0%
# runtime - 0.0%

# %%
#check datatypes
df1.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df1=df1.dropna()

# %%
df1['budget'].astype('int64')
df1['gross'].astype('int64')
df1['votes'].astype('int64')
# Out:
# 0        927000
# 1         65000
# 2       1200000
# 3        221000
# 4        108000
#          ...
# 7648     140000
# 7649     102000
# 7650      53000
# 7651      42000
# 7652       3700
# Name: votes, Length: 5421, dtype: int64

# %%
#sort values on gross column
df1.sort_values(by=['gross'] , inplace=False , ascending=False)
# Out:
#                                             name     rating   genre  year  \
# 5445                                      Avatar      PG-13  Action  2009
# 7445                           Avengers: Endgame      PG-13  Action  2019
# 3045                                     Titanic      PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens      PG-13  Action  2015
# 7244                      Avengers: Infinity War      PG-13  Action  2018
# ...                                          ...        ...     ...   ...
# 5640                                 Tanner Hall          R   Drama  2009
# 2434                  Philadelphia Experiment II      PG-13  Action  1993
# 3681                                Ginger Snaps  Not Rated   Drama  2000
# 272                                     Parasite          R  Horror  1982
# 3203                                  Trojan War      PG-13  Comedy  1997
#
#                                released  score    votes             director  \
# ...

# %%
#plotting scatter graph between budget and gross

plt.scatter(x=df1['budget'] ,y=df1['gross'])

plt.title('Gross VS Budget')

plt.xlabel('Budget of film')

plt.ylabel('Gross earning of film')

plt.show()

# %%
#plotting regression graph for better visulaisation 

sns.regplot(x='budget' , y='gross', data=df1 ,scatter_kws={"color":"Red"}, line_kws={"color":"Black"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
df1.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
#our guess is correct high corrleatio between budget and gross

corr_matrix=df.corr()
sns.heatmap(corr_matrix,annot=True)
plt.show()
